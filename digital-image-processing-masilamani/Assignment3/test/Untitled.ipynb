# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('lena_test.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1000, 1500, 3)
