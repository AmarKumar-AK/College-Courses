# %%
import cv2
import matplotlib.pyplot as plt

# %%
lena = cv2.imread('lena.png')
lena = cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)
plt.imshow(lena)

# %%
cropped_lena = lena[int(lena.shape[0]/4) : int(3*lena.shape[0]/4) , int(lena.shape[1]/4) : int(3*lena.shape[1]/4)]

# %%
plt.imshow(cropped_lena)
